# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def reduce_noise_and_smooth(input_folder, output_folder, kernel_size=(69, 69)):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Get a list of all files in the input folder
    image_files = [f for f in os.listdir(input_folder) if f.endswith('.jpg') or f.endswith('.png')]

    # Apply Gaussian blur to each image and save the smoothed version
    for image_file in image_files:
        input_path = os.path.join(input_folder, image_file)
        output_path = os.path.join(output_folder, image_file)

        # Read the image
        img = cv2.imread(input_path)

        # Apply Gaussian blur with the specified kernel size
        blurred = cv2.GaussianBlur(img, kernel_size, 0)

        # Save the smoothed image
        cv2.imwrite(output_path, blurred)

# %%
image_path = '/content/drive/My Drive/CustomObjDet/data/runs/detect/cropped2/'
output_path = '/content/drive/My Drive/CustomObjDet/data/runs/detect/out_image_smoothed/'
reduce_noise_and_smooth(image_path, output_path)

# %%
image_path = '/content/drive/My Drive/CustomObjDet/data/runs/detect/img/'
output_path = '/content/drive/My Drive/CustomObjDet/data/runs/detect/ref_img_smoothed/'
reduce_noise_and_smooth(image_path, output_path)
